# %% [markdown]
# ### RapidFire AI Tutorial Use Case: SFT for Customer Support Q&A Chatbot

# %% [markdown]
# ##### Note: This FSDP demo uses `NUM_GPUS = torch.cuda.device_count()` (minimum 1). The original recipe targeted 4× A10 GPUs; on smaller machines it still runs with fewer GPUs. Data is heavily downsampled for demo purposes.

# %%
import torch
from rapidfireai import Experiment
from rapidfireai.automl import List, RFGridSearch, RFModelConfig, RFLoraConfig, RFSFTConfig

NUM_GPUS = max(1, int(torch.cuda.device_count()))
print(f"NUM_GPUS={NUM_GPUS} (torch.cuda.device_count()={torch.cuda.device_count()})")
# Out:
# NUM_GPUS=1 (torch.cuda.device_count()=1)

# %% [markdown]
# ### Load Dataset and Specify Train and Eval Partitions

# %%
from datasets import load_dataset

dataset=load_dataset("bitext/Bitext-customer-support-llm-chatbot-training-dataset")

train_dataset=dataset["train"].select(range(320))
eval_dataset=dataset["train"].select(range(320,328))
train_dataset=train_dataset.shuffle(seed=42)
eval_dataset=eval_dataset.shuffle(seed=42)

# %% [markdown]
# ### Define Data Processing Function

# %%
def sample_formatting_function(row):
    """Function to preprocess each example from dataset"""
    # Special tokens for formatting
    SYSTEM_PROMPT = "You are a helpful and friendly customer support assistant. Please answer the user's query to the best of your ability."
    return {
        "prompt": [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": row["instruction"]},
            
        ],
        "completion": [
            {"role": "assistant", "content": row["response"]}
        ]
    }

# %% [markdown]
# ### Initialize Experiment

# %%
# Every experiment instance must be uniquely named
experiment = Experiment(experiment_name="exp1-chatqa-fsdp")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/rapidfireai/rapidfireai/fit/db/db_interface.py:42, in DatabaseInterface.__init__(self)
#      32 pragma_sql = f"""
#      33 PRAGMA cache_size={DBConfig.CACHE_SIZE};
#      34 PRAGMA mmap_size={DBConfig.MMAP_SIZE};
#    (...)     40 PRAGMA foreign_keys=ON;
#      41 """
# ---> 42 _ = self.conn.executescript(pragma_sql)
#      44 self.cursor: sqlite3.Cursor = self.conn.cursor()
#
# OperationalError: disk I/O error
#
# The above exception was the direct cause of the following exception:
#
# DBException                               Traceback (most recent call last)
# File ~/rapidfireai/rapidfireai/experiment.py:192, in Experiment._init_fit_mode(self)
#     191 try:
# --> 192     RfDb().create_tables()
#     193 except Exception as e:
#
# File ~/rapidfireai/rapidfireai/fit/db/rf_db.py:30, in RfDb.__init__(self)
#      29 def __init__(self):
# ---> 30     self.db: DatabaseInterface = DatabaseInterface()
#
# File ~/rapidfireai/rapidfireai/fit/db/db_interface.py:47, in DatabaseInterface.__init__(self)
#      46 except sqlite3.Error as e:
# ---> 47     raise DBException(f"Failed to initialize database connection: {e}") from e
#      48 except Exception as e:
#
# DBException: Failed to initialize database connection: disk I/O error
#
# The above exception was the direct cause of the following exception:
#
# ExperimentException                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Every experiment instance must be uniquely named
# ----> 2 experiment = Experiment(experiment_name="exp1-chatqa-fsdp")
#
# File ~/rapidfireai/rapidfireai/experiment.py:91, in Experiment.__init__(self, experiment_name, mode, experiment_path, num_cpus, num_gpus)
#      89 # Initialize based on mode
#      90 if mode == "fit":
# ---> 91     self._init_fit_mode()
#      92 else:
#      93     self._ray_resource_config = self._auto_detect_resources(num_cpus=num_cpus, num_gpus=num_gpus)
#
# File ~/rapidfireai/rapidfireai/experiment.py:194, in Experiment._init_fit_mode(self)
#     192     RfDb().create_tables()
#     193 except Exception as e:
# --> 194     raise ExperimentException(f"Error creating db tables: {e}, traceback: {traceback.format_exc()}") from e
#     196 # Store database reference
#     197 self.db = RfDb()
#
# ExperimentException: Error creating db tables: Failed to initialize database connection: disk I/O error, traceback: Traceback (most recent call last):
#   File "/home/rapid-fire/rapidfireai/rapidfireai/fit/db/db_interface.py", line 42, in __init__
#     _ = self.conn.executescript(pragma_sql)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# sqlite3.OperationalError: disk I/O error
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/rapid-fire/rapidfireai/rapidfireai/experiment.py", line 192, in _init_fit_mode
#     RfDb().create_tables()
#     ^^^^^^
#   File "/home/rapid-fire/rapidfireai/rapidfireai/fit/db/rf_db.py", line 30, in __init__
#     self.db: DatabaseInterface = DatabaseInterface()
#                                  ^^^^^^^^^^^^^^^^^^^
#   File "/home/rapid-fire/rapidfireai/rapidfireai/fit/db/db_interface.py", line 47, in __init__
#     raise DBException(f"Failed to initialize database connection: {e}") from e
# rapidfireai.fit.utils.exceptions.DBException: Failed to initialize database connection: disk I/O error

# %% [markdown]
# ### Define Custom Eval Metrics Function

# %%
def sample_compute_metrics(eval_preds):  
    """Optional function to compute eval metrics based on predictions and labels"""
    predictions, labels = eval_preds

    # Standard text-based eval metrics: Rouge and BLEU
    import evaluate
    rouge = evaluate.load("rouge")
    bleu = evaluate.load("bleu")

    rouge_output = rouge.compute(predictions=predictions, references=labels, use_stemmer=True)
    rouge_l = rouge_output["rougeL"]
    bleu_output = bleu.compute(predictions=predictions, references=labels)
    bleu_score = bleu_output["bleu"]

    return {
        "rougeL": round(rouge_l, 4),
        "bleu": round(bleu_score, 4),
    }

# %% [markdown]
# ### Define Multi-Config Knobs for Model, LoRA, and SFT Trainer using RapidFire AI Wrapper APIs

# %%
# 2 LoRA PEFT configs lite with different adapter capacities
peft_configs_lite = List([
    RFLoraConfig(
        r=8,
        lora_alpha=16,
        lora_dropout=0.05,
        target_modules=["q_proj", "v_proj"], 
        bias="none"
    ),
    RFLoraConfig(
        r=16,
        lora_alpha=16,
        lora_dropout=0.05,
        target_modules=["q_proj", "v_proj","k_proj"], 
        bias="none"
    ),
])

# 2 combinations in total
config_set_lite = List([
    RFModelConfig(
        model_name="Qwen/Qwen3-32B",  # 32B model
        peft_config=peft_configs_lite,
        training_args=RFSFTConfig(
            learning_rate=1e-4,  
            lr_scheduler_type="linear",
            per_device_train_batch_size=1,
            per_device_eval_batch_size=1,
            num_train_epochs=1,
            gradient_accumulation_steps=4,   
            logging_steps=1,
            eval_strategy="steps",
            eval_steps=6,
            gradient_checkpointing=True,
            gradient_checkpointing_kwargs={"use_reentrant": False},
            bf16=True,
            tf32=True,
            max_length=256,
            fsdp="full_shard auto_wrap",
            fsdp_config={"backward_prefetch": "backward_pre","forward_prefetch": False,"use_orig_params": False,  "cpu_ram_efficient_loading": True,"offload_params": True, "sync_module_states": True,"limit_all_gathers": True, "sharding_strategy": "FULL_SHARD",
                "auto_wrap_policy": "TRANSFORMER_BASED_WRAP",
                "transformer_layer_cls_to_wrap": ["Qwen3DecoderLayer"]},
            fsdp_transformer_layer_cls_to_wrap="Qwen3DecoderLayer",   
        ),
        model_type="causal_lm",
        model_kwargs={"device_map":None, "torch_dtype": "bfloat16", "use_cache": False},
        formatting_func=sample_formatting_function,
        compute_metrics = sample_compute_metrics,
        generation_config={
            "max_new_tokens": 128,
            "do_sample": False,
            "use_cache": True,
        }

    )
])

# %% [markdown]
# #### Define Model Creation Function for All Model Types Across Configs

# %%
def sample_create_model(model_config): 
     """Function to create model object for any given config; must return tuple of (model, tokenizer)"""
     from transformers import AutoModelForCausalLM, AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForMaskedLM, GptOssForCausalLM

     model_name = model_config["model_name"]
     model_type = model_config["model_type"]
     model_kwargs = model_config["model_kwargs"]
     
 
     if model_type == "causal_lm":
          model = AutoModelForCausalLM.from_pretrained(model_name, **model_kwargs)
     elif model_type == "gpt":                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
          model = GptOssForCausalLM.from_pretrained(model_name, **model_kwargs)
     elif model_type == "seq2seq_lm":
          model = AutoModelForSeq2SeqLM.from_pretrained(model_name, **model_kwargs)
     elif model_type == "masked_lm":
          model = AutoModelForMaskedLM.from_pretrained(model_name, **model_kwargs)
     elif model_type == "custom":
          # Handle custom model loading logic, e.g., loading your own checkpoints
          # model = ... 
          pass
     else:
          # Default to causal LM
          model = AutoModelForCausalLM.from_pretrained(model_name, **model_kwargs)
      
     tokenizer = AutoTokenizer.from_pretrained(model_name)
     model.gradient_checkpointing_enable(gradient_checkpointing_kwargs={"use_reentrant": False})
     return (model,tokenizer)

# %% [markdown]
# #### Generate Config Group

# %%
# Simple grid search across all sets of config knob values = 4 combinations in total
config_group = RFGridSearch(
    configs=config_set_lite,
    trainer_type="SFT"
)

# %% [markdown]
# ### Run Multi-Config Training

# %%
# Launch training of all configs in the config_group with swap granularity of 4 chunks
experiment.run_fit(
    config_group,
    sample_create_model,
    train_dataset,
    eval_dataset,
    num_chunks=4,
    seed=42,
    num_gpus=NUM_GPUS,
)

# %% [markdown]
# ### End Current Experiment

# %%
experiment.end()
