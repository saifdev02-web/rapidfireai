# %% [markdown]
# <div align="center">
# <a href="https://rapidfire.ai/"><img src="https://raw.githubusercontent.com/RapidFireAI/rapidfireai/main/docs/images/RapidFire - Blue bug -white text.svg" width="115"></a>
# <a href="https://discord.gg/6vSTtncKNN"><img src="https://raw.githubusercontent.com/RapidFireAI/rapidfireai/main/docs/images/discord-button.svg" width="145"></a>
# <a href="https://oss-docs.rapidfire.ai/"><img src="https://raw.githubusercontent.com/RapidFireAI/rapidfireai/main/docs/images/documentation-button.svg" width="125"></a>
# <br/>
# Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/RapidFireAI/rapidfireai">GitHub</a></i> ⭐
# <br/>
# To install RapidFire AI on your own machine, see the <a href="https://oss-docs.rapidfire.ai/en/latest/walkthrough.html">Install and Get Started</a> guide in our docs.
# </div>

# %% [markdown]
# ### RapidFire AI Tutorial Use Case: SFT for Customer Support Q&A Chatbot

# %%
import torch
from rapidfireai import Experiment
from rapidfireai.automl import List, RFGridSearch, RFModelConfig, RFLoraConfig, RFSFTConfig

# Match RapidFire worker count to visible CUDA GPUs on this machine
NUM_GPUS = max(1, int(torch.cuda.device_count()))
print(f"NUM_GPUS={NUM_GPUS} (torch.cuda.device_count()={torch.cuda.device_count()})")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import torch
#       2 from rapidfireai import Experiment
# ----> 3 from rapidfireai.automl import List, RFGridSearch, RFModelConfig, RFLoraConfig, RFSFTConfig
#       4
#       5 # Match RapidFire worker count to visible CUDA GPUs on this machine
#       6 NUM_GPUS = max(1, int(torch.cuda.device_count()))
#
# File ~/rapidfireai/rapidfireai/automl/__init__.py:11
#       9 # Import fit mode configs (conditionally available)
#      10 try:
# ---> 11     from .model_config import (
#      12         RFDPOConfig,
#      13         RFGRPOConfig,
#      14         RFLoraConfig,
#      15         RFModelConfig,
#      16         RFSFTConfig,
#      17     )
#      18     _FIT_CONFIGS_AVAILABLE = True
#      19 except (ImportError, AttributeError, TypeError):
#
# File ~/rapidfireai/rapidfireai/automl/model_config.py:16
#      14 # Fit mode dependencies (peft, trl)
#      15 try:
# ---> 16     from peft import LoraConfig
#      17     from trl import DPOConfig, GRPOConfig, SFTConfig
#      19     _FIT_DEPS_AVAILABLE = True
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/peft/__init__.py:17
#       1 # Copyright 2023-present the HuggingFace Inc. team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "0.18.1"
# ---> 17 from .auto import (
#      18     MODEL_TYPE_TO_PEFT_MODEL_MAPPING,
#      19     AutoPeftModel,
#      20     AutoPeftModelForCausalLM,
#      21     AutoPeftModelForFeatureExtraction,
#      22     AutoPeftModelForQuestionAnswering,
#      23     AutoPeftModelForSeq2SeqLM,
#      24     AutoPeftModelForSequenceClassification,
#      25     AutoPeftModelForTokenClassification,
#      26 )
#      27 from .config import PeftConfig, PromptLearningConfig
#      28 from .mapping import (
#      29     PEFT_TYPE_TO_CONFIG_MAPPING,
#      30     PEFT_TYPE_TO_MIXED_MODEL_MAPPING,
#    (...)     33     inject_adapter_in_model,
#      34 )
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/peft/auto.py:21
#      18 import os
#      19 from typing import Optional
# ---> 21 from transformers import (
#      22     AutoModel,
#      23     AutoModelForCausalLM,
#      24     AutoModelForQuestionAnswering,
#      25     AutoModelForSeq2SeqLM,
#      26     AutoModelForSequenceClassification,
#      27     AutoModelForTokenClassification,
#      28     AutoTokenizer,
#      29 )
#      31 from .config import PeftConfig
#      32 from .peft_model import (
#      33     PeftModel,
#      34     PeftModelForCausalLM,
#    (...)     39     PeftModelForTokenClassification,
#      40 )
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/transformers/models/auto/modeling_auto.py:23
#      20 from typing import TYPE_CHECKING, Union
#      22 from ...utils import logging
# ---> 23 from .auto_factory import (
#      24     _BaseAutoBackboneClass,
#      25     _BaseAutoModelClass,
#      26     _LazyAutoMapping,
#      27     auto_class_update,
#      28 )
#      29 from .configuration_auto import CONFIG_MAPPING_NAMES
#      32 if TYPE_CHECKING:
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:43
#      39 from .configuration_auto import AutoConfig, model_type_to_module_name, replace_list_option_in_docstrings
#      42 if is_torch_available():
# ---> 43     from ...generation import GenerationMixin
#      46 logger = logging.get_logger(__name__)
#      48 _T = TypeVar("_T")
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/transformers/generation/utils.py:43
#      41 from ..integrations.deepspeed import is_deepspeed_zero3_enabled
#      42 from ..integrations.fsdp import is_fsdp_managed_module
# ---> 43 from ..masking_utils import create_masks_for_generate
#      44 from ..pytorch_utils import isin_mps_friendly
#      45 from ..tokenization_utils import ExtensionsTrie
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/transformers/masking_utils.py:40
#      37 _is_torch_xpu_available = is_torch_xpu_available()
#      39 if _is_torch_greater_or_equal_than_2_6:
# ---> 40     from torch._dynamo._trace_wrapped_higher_order_op import TransformGetItemToIndex
#      43 logger = logging.get_logger(__name__)
#      46 def and_masks(*mask_functions: Callable) -> Callable:
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     config,
#      16     convert_frame,
#      17     eval_frame,
#      18     functional_export,
#      19     resume_execution,
#      20 )
#      21 from .backends.registry import list_backends, lookup_backend, register_backend
#      22 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/aot_compile.py:15
#      13 import torch
#      14 import torch.fx
# ---> 15 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      16 from torch._dynamo.graph_utils import _graph_device_type
#      17 from torch._dynamo.package import SystemInfo
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:62
#      60 from torch._dynamo.callback import CallbackTrigger
#      61 from torch._dynamo.distributed import get_compile_pg
# ---> 62 from torch._dynamo.symbolic_convert import TensorifyState
#      63 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      64 from torch._logging import structured
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:60
#      57 from torch.fx.experimental.symbolic_shapes import guard_bool
#      58 from torch.utils._functools import cache_method
# ---> 60 from . import (
#      61     config,
#      62     exc,
#      63     graph_break_hints,
#      64     logging as torchdynamo_logging,
#      65     trace_rules,
#      66     variables,
#      67 )
#      68 from .bytecode_analysis import (
#      69     get_indexof,
#      70     JUMP_OPNAMES,
#      71     livevars_analysis,
#      72     propagate_line_nums,
#      73 )
#      74 from .bytecode_transformation import (
#      75     cleaned_instructions,
#      76     create_binary_slice,
#    (...)     89     unique_id,
#      90 )
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/trace_rules.py:59
#      51 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      52 from .utils import (
#      53     getfile,
#      54     hashable,
#    (...)     57     unwrap_if_wrapper,
#      58 )
# ---> 59 from .variables import (
#      60     BuiltinVariable,
#      61     FunctionalCallVariable,
#      62     FunctorchHigherOrderVariable,
#      63     InspectSignatureVariable,
#      64     LocalGeneratorFunctionVariable,
#      65     LocalGeneratorObjectVariable,
#      66     NestedUserFunctionVariable,
#      67     PolyfilledFunctionVariable,
#      68     PyTreeGetNodeTypeFunctionVariable,
#      69     PyTreeTreeIsLeafFunctionVariable,
#      70     ReparametrizeModuleCallVariable,
#      71     SkipFunctionVariable,
#      72     SparseTensorCreationSkipVariable,
#      73     TorchInGraphFunctionVariable,
#      74     UserFunctionVariable,
#      75     UserMethodVariable,
#      76 )
#      77 from .variables.base import VariableTracker
#      80 np: Optional[types.ModuleType] = None
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/variables/__init__.py:19
#       1 """
#       2 This package implements variable tracking and symbolic execution capabilities for Dynamo,
#       3 which are essential for converting Python code into FX graphs. It provides a comprehensive
#    (...)     16 allows Dynamo to accurately trace and optimize Python code while preserving its semantics.
#      17 """
# ---> 19 from .base import VariableTracker
#      20 from .builtin import BuiltinVariable
#      21 from .constant import CONSTANT_VARIABLE_NONE, ConstantVariable, EnumVariable
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/variables/base.py:929
#     925         return " ".join(map(typestr, objs))
#     928 instancecheck = type.__instancecheck__
# --> 929 from . import builder
#     930 from .lazy import LazyVariableTracker
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/variables/builder.py:110
#     102 from ..guards import GuardBuilder, install_guard, make_dupe_guard
#     103 from ..pgo import (
#     104     auto_dynamic,
#     105     auto_unset,
#    (...)    108     process_automatic_dynamic,
#     109 )
# --> 110 from ..side_effects import SideEffects
#     111 from ..source import (
#     112     AttrProxySource,
#     113     AttrSource,
#    (...)    141     UnspecializedNNModuleSource,
#     142 )
#     143 from ..utils import (
#     144     _extract_tensor_dict,
#     145     build_checkpoint_variable,
#    (...)    175     wrap_fake_exception,
#     176 )
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/side_effects.py:46
#      39 from . import config, graph_break_hints, utils, variables
#      40 from .bytecode_transformation import (
#      41     bytecode_from_template,
#      42     create_call_function,
#      43     create_call_method,
#      44     create_instruction,
#      45 )
# ---> 46 from .codegen import PyCodegen
#      47 from .exc import collapse_resume_frames, get_stack_above_dynamo, unimplemented
#      48 from .source import GlobalSource, LocalCellSource, Source, TempLocalSource
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/codegen.py:50
#      45 from .variables.functions import (
#      46     ContextlibContextManagerLocalGeneratorObjectVariable,
#      47     LocalGeneratorObjectVariable,
#      48 )
#      49 from .variables.nn_module import NNModuleVariable
# ---> 50 from .variables.tensor import (
#      51     NumpyNdarrayVariable,
#      52     SymNodeVariable,
#      53     TensorVariable,
#      54     UnspecializedPythonVariable,
#      55 )
#      56 from .variables.torch_function import TensorWithTFOverrideVariable
#      59 if TYPE_CHECKING:
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/variables/tensor.py:48
#      45 from torch.utils._python_dispatch import is_traceable_wrapper_subclass
#      47 from .. import config, graph_break_hints, variables
# ---> 48 from .._trace_wrapped_higher_order_op import trace_wrapped
#      49 from ..exc import (
#      50     TorchRuntimeError,
#      51     unimplemented,
#    (...)     54     UserErrorType,
#      55 )
#      56 from ..external_utils import _ApplyBackwardHook, call_hook_from_backward_state
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_dynamo/_trace_wrapped_higher_order_op.py:52
#      46 Tensor = torch.Tensor
#      49 __all__ = ["trace_wrapped"]
# ---> 52 @torch.library.custom_op("flex_lib::zeros_and_scatter", mutates_args=())  # type: ignore[misc]
#      53 def zeros_and_scatter(
#      54     shape: list[int],
#      55     indices: list[Tensor],
#      56     vals: Tensor,
#      57 ) -> Tensor:
#      58     """Custom Op so that we can register a custom lowering for the new_output + scatter in the backwards pass"""
#      59     grad = torch.zeros(shape, device=vals.device, dtype=vals.dtype)
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_library/custom_ops.py:157, in custom_op.<locals>.inner(fn)
#     154     schema_str = schema
#     156 namespace, opname = name.split("::")
# --> 157 result = CustomOpDef(namespace, opname, schema_str, fn, tags)
#     158 if schema is not None:
#     159     # Check that schema's alias annotations match those of `mutates_args`.
#     160     expected = set()
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_library/custom_ops.py:215, in CustomOpDef.__init__(self, namespace, name, schema, fn, tags)
#     212 self._autocast_cpu_dtype: Optional[_dtype] = None
#     214 self._lib = get_library_allowing_overwrite(self._namespace, self._name)
# --> 215 self._register_to_dispatcher(self._tags)
#     216 self._disabled_kernel: set = set()
#     217 self._used_triton_kernels: list[Any] = list()
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_library/custom_ops.py:638, in CustomOpDef._register_to_dispatcher(self, tags)
#     630         raise RuntimeError(
#     631             f"There was no fake impl registered for {self}. "
#     632             f"This is necessary for torch.compile/export/fx tracing to work. "
#     633             f"Please use `{self._init_fn.__name__}.register_fake` to add an "
#     634             f"fake impl."
#     635         )
#     636     return self._abstract_fn(*args, **kwargs)
# --> 638 lib._register_fake(self._name, fake_impl, _stacklevel=4)
#     640 autograd_impl = autograd.make_autograd_impl(self._opoverload, self)
#     641 lib.impl(self._name, autograd_impl, "Autograd", with_keyset=True)
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/library.py:183, in Library._register_fake(self, op_name, fn, _stacklevel, allow_override)
#     180 def _register_fake(self, op_name, fn, _stacklevel=1, *, allow_override=False):
#     181     r"""Registers the fake impl for an operator defined in the library."""
# --> 183     source = torch._library.utils.get_source(_stacklevel + 1)
#     184     frame = sys._getframe(_stacklevel)
#     185     caller_module = inspect.getmodule(frame)
#
# File ~/rapidfireai/venv/lib/python3.12/site-packages/torch/_library/utils.py:45, in get_source(stacklevel)
#      36 def get_source(stacklevel: int) -> str:
#      37     """Get a string that represents the caller.
#      38
#      39     Example: "/path/to/foo.py:42"
#    (...)     43     etc.
#      44     """
# ---> 45     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#      46     source = f"{frame.filename}:{frame.lineno}"
#      47     return source
#
# File /usr/lib/python3.12/inspect.py:1707, in getframeinfo(frame, context)
#    1705 start = lineno - 1 - context//2
#    1706 try:
# -> 1707     lines, lnum = findsource(frame)
#    1708 except OSError:
#    1709     lines = index = None
#
# File /usr/lib/python3.12/inspect.py:1083, in findsource(object)
#    1080     if not (file.startswith('<') and file.endswith('>')):
#    1081         raise OSError('source code not available')
# -> 1083 module = getmodule(object, file)
#    1084 if module:
#    1085     lines = linecache.getlines(file, module.__dict__)
#
# File /usr/lib/python3.12/inspect.py:1009, in getmodule(object, _filename)
#    1006         f = getabsfile(module)
#    1007         # Always map to the name the module knows itself by
#    1008         modulesbyfile[f] = modulesbyfile[
# -> 1009             os.path.realpath(f)] = module.__name__
#    1010 if file in modulesbyfile:
#    1011     return sys.modules.get(modulesbyfile[file])
#
# File <frozen posixpath>:432, in realpath(filename, strict)
#     428 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen posixpath>:477, in _joinrealpath(path, rest, strict, seen)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Load Dataset and Specify Train and Eval Partitions

# %%
from datasets import load_dataset

dataset=load_dataset("bitext/Bitext-customer-support-llm-chatbot-training-dataset")

# Select a subset of the dataset for demo purposes
train_dataset=dataset["train"].select(range(128))
eval_dataset=dataset["train"].select(range(128,152))
train_dataset=train_dataset.shuffle(seed=42)
eval_dataset=eval_dataset.shuffle(seed=42)

# %% [markdown]
# ### Define Data Processing Function

# %%
def sample_formatting_function(row):
    """Function to preprocess each example from dataset"""
    # Special tokens for formatting
    SYSTEM_PROMPT = "You are a helpful and friendly customer support assistant. Please answer the user's query to the best of your ability."
    return {
        "prompt": [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": row["instruction"]},
            
        ],
        "completion": [
            {"role": "assistant", "content": row["response"]}
        ]
    }

# %% [markdown]
# ### Initialize Experiment

# %%
# Every experiment instance must be uniquely named
experiment = Experiment(experiment_name="exp1-chatqa-lite", mode="fit")

# %% [markdown]
# ### Define Custom Eval Metrics Function

# %%
def sample_compute_metrics(eval_preds):  
    """Optional function to compute eval metrics based on predictions and labels"""
    predictions, labels = eval_preds

    # Standard text-based eval metrics: Rouge and BLEU
    import evaluate
    rouge = evaluate.load("rouge")
    bleu = evaluate.load("bleu")

    rouge_output = rouge.compute(predictions=predictions, references=labels, use_stemmer=True)
    rouge_l = rouge_output["rougeL"]
    bleu_output = bleu.compute(predictions=predictions, references=labels)
    bleu_score = bleu_output["bleu"]

    return {
        "rougeL": round(rouge_l, 4),
        "bleu": round(bleu_score, 4),
    }

# %% [markdown]
# ### Define Multi-Config Knobs for Model, LoRA, and SFT Trainer using RapidFire AI Wrapper APIs

# %%
# 2 LoRA PEFT configs lite with different adapter capacities
peft_configs_lite = List([
    RFLoraConfig(
        r=8,
        lora_alpha=16,
        lora_dropout=0.1,
        target_modules=["q_proj", "v_proj"],  # Standard transformer naming
        bias="none"
    ),
    RFLoraConfig(
        r=32,
        lora_alpha=64,
        lora_dropout=0.1,
        target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],  # Standard naming
        bias="none"
    )
])

# 2 base models x 2 peft configs = 4 combinations in total
config_set_lite = List([
    RFModelConfig(
        model_name="TinyLlama/TinyLlama-1.1B-Chat-v1.0",  # 1.1B model
        peft_config=peft_configs_lite,
        training_args=RFSFTConfig(
            learning_rate=1e-3,  # Higher LR for very small model
            lr_scheduler_type="linear",
            per_device_train_batch_size=4,
            per_device_eval_batch_size=4,
            max_steps=128,
            gradient_accumulation_steps=1,   # No accumulation needed
            logging_steps=2,
            eval_strategy="steps",
            eval_steps=4,
            bf16=True,
        ),
        model_type="causal_lm",
        model_kwargs={"device_map": "auto", "torch_dtype": "auto", "use_cache": False},
        formatting_func=sample_formatting_function,
        compute_metrics=sample_compute_metrics,
        generation_config={
            "max_new_tokens": 256,
            "temperature": 0.8,  # Higher temp for tiny model
            "top_p": 0.9,
            "top_k": 30,         # Reduced top_k
            "repetition_penalty": 1.05,
        }
    ),
    RFModelConfig(
        model_name="TinyLlama/TinyLlama-1.1B-Chat-v1.0",  # 1.1B model
        peft_config=peft_configs_lite,
        training_args=RFSFTConfig(
            learning_rate=1e-4,  # Higher LR for very small model
            lr_scheduler_type="linear",
            per_device_train_batch_size=4,  # Even larger batch size
            per_device_eval_batch_size=4,
            max_steps=128,
            gradient_accumulation_steps=1,   # No accumulation needed
            logging_steps=2,
            eval_strategy="steps",
            eval_steps=4,
            bf16=True,
        ),
        model_type="causal_lm",
        model_kwargs={"device_map": "auto", "torch_dtype": "auto", "use_cache": False},
        formatting_func=sample_formatting_function,
        compute_metrics=sample_compute_metrics,
        generation_config={
            "max_new_tokens": 256,
            "temperature": 0.8,  # Higher temp for tiny model
            "top_p": 0.9,
            "top_k": 30,         # Reduced top_k
            "repetition_penalty": 1.05,
        }
    )
])

# %% [markdown]
# #### Define Model Creation Function for All Model Types Across Configs

# %%
def sample_create_model(model_config): 
     """Function to create model object for any given config; must return tuple of (model, tokenizer)"""
     from transformers import AutoModelForCausalLM, AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForMaskedLM

     model_name = model_config["model_name"]
     model_type = model_config["model_type"]
     model_kwargs = model_config["model_kwargs"]
 
     if model_type == "causal_lm":
          model = AutoModelForCausalLM.from_pretrained(model_name, **model_kwargs)
     elif model_type == "seq2seq_lm":
          model = AutoModelForSeq2SeqLM.from_pretrained(model_name, **model_kwargs)
     elif model_type == "masked_lm":
          model = AutoModelForMaskedLM.from_pretrained(model_name, **model_kwargs)
     elif model_type == "custom":
          # Handle custom model loading logic, e.g., loading your own checkpoints
          # model = ... 
          pass
     else:
          # Default to causal LM
          model = AutoModelForCausalLM.from_pretrained(model_name, **model_kwargs)
      
     tokenizer = AutoTokenizer.from_pretrained(model_name)
      
     return (model,tokenizer)

# %% [markdown]
# #### Generate Config Group

# %%
# Simple grid search across all sets of config knob values = 4 combinations in total
config_group = RFGridSearch(
    configs=config_set_lite,
    trainer_type="SFT"
)

# %% [markdown]
# ### Run Multi-Config Training

# %%
# Launch training of all configs in the config_group with swap granularity of 4 chunks
experiment.run_fit(
    config_group,
    sample_create_model,
    train_dataset,
    eval_dataset,
    num_chunks=4,
    seed=42,
    num_gpus=NUM_GPUS,
)

# %% [markdown]
# ### End Current Experiment

# %%
experiment.end()

# %% [markdown]
# <div align="center">
# <a href="https://rapidfire.ai/"><img src="https://raw.githubusercontent.com/RapidFireAI/rapidfireai/main/docs/images/RapidFire - Blue bug -white text.svg" width="115"></a>
# <a href="https://discord.gg/6vSTtncKNN"><img src="https://raw.githubusercontent.com/RapidFireAI/rapidfireai/main/docs/images/discord-button.svg" width="145"></a>
# <a href="https://oss-docs.rapidfire.ai/"><img src="https://raw.githubusercontent.com/RapidFireAI/rapidfireai/main/docs/images/documentation-button.svg" width="125"></a>
# <br/>
# Thanks for trying RapidFire AI! ⭐ <i>Star us on <a href="https://github.com/RapidFireAI/rapidfireai">GitHub</a></i> ⭐
# </div>
